# %%
import os
from dotenv import load_dotenv

import pandas as pd
from sqlalchemy import create_engine

# %%
def load_database():

    load_dotenv()

    DB_NAME = os.getenv("DB_NAME")
    DB_USER = os.getenv('DB_USER')
    DB_PASSWORD = os.getenv('DB_PASSWORD')
    HOST = os.getenv('HOST')
    PORT = os.getenv('PORT')

    engine_string = "postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}".format(
        user = DB_USER,
        password = DB_PASSWORD,
        host = HOST,
        port = PORT,
        database = DB_NAME,
    )
    
    return create_engine(engine_string)

    
engine = load_database()

# %%
# table = db['TABLES'][0]
df = pd.read_sql_table('mobility_google', engine)

# %%
df.head()
# Out:
#   country_region_code country_region sub_region_1 sub_region_2 metro_area  \
# 0                  AF    Afghanistan         None         None       None
# 1                  AF    Afghanistan         None         None       None
# 2                  AF    Afghanistan         None         None       None
# 3                  AF    Afghanistan         None         None       None
# 4                  AF    Afghanistan         None         None       None
#
#   iso_3166_2_code census_fips_code                     place_id       date  \
# 0            None             None  ChIJbQL_-LZu0TgReNqWvg1GtfM 2020-03-31
# 1            None             None  ChIJbQL_-LZu0TgReNqWvg1GtfM 2020-04-01
# 2            None             None  ChIJbQL_-LZu0TgReNqWvg1GtfM 2020-04-02
# 3            None             None  ChIJbQL_-LZu0TgReNqWvg1GtfM 2020-04-03
# 4            None             None  ChIJbQL_-LZu0TgReNqWvg1GtfM 2020-04-04
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                              -43.0
# 1                                              -44.0
# 2                                              -44.0
# 3                                              -38.0
# 4                                              -43.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                              -29.0
# 1                                              -24.0
# 2                                              -25.0
# 3                                              -13.0
# 4                                              -20.0
#
#    parks_percent_change_from_baseline  \
# 0                               -14.0
# 1                                -9.0
# 2                               -10.0
# 3                                -8.0
# 4                               -11.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                          -42.0
# 1                                          -38.0
# 2                                          -35.0
# 3                                          -32.0
# 4                                          -38.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                    -38.0
# 1                                    -37.0
# 2                                    -35.0
# 3                                    -12.0
# 4                                    -34.0
#
#    residential_percent_change_from_baseline
# 0                                      12.0
# 1                                      11.0
# 2                                      13.0
# 3                                       6.0
# 4                                      10.0
